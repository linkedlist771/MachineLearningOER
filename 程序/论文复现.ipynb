# %% [markdown]
# # 导入机器学习以及数据处理库

# %%
from autogluon.tabular import TabularDataset , TabularPredictor
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# e:\Anaconda\envs\pytorch\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # 处理数据
#
#
# 需要对PDF导出的数据进行一下预处理
# ```python
#
#
# ```

# %%
train_data = pd.read_excel("../数据/数据.xlsx", dtype="str")
train_data
# Out:
#       VEN      𝑹𝑨𝑴   𝑨𝑵   𝑹𝑨   𝑹𝑪  𝑭𝑰𝑬       𝑬𝑨   𝑬𝑷   𝑫𝑬 𝜹𝑽𝑬𝑵 𝜹𝑹𝑨𝑴  𝜹𝑨𝑵  𝜹𝑹𝑨  \
# 0      10  58. 693   28  1.9  1.1  737      111  1.9    8    0    0    0    0
# 1     NaN      NaN  NaN    7    7  .12      .53    1  NaN  NaN  NaN  NaN  NaN
# 2     NaN      NaN  NaN  NaN  NaN    9        7  NaN  NaN  NaN  NaN  NaN  NaN
# 3     9.9      58.  27.  1.9  1.1  737      108  1.9   7.  0.1  0.2  0.1  0.0
# 4      38      604   93   72   72  .91      .53   07    9  201  436  201  001
# ...   ...      ...  ...  ...  ...  ...      ...  ...  ...  ...  ...  ...  ...
# 1965   69      837   96   01   81  .46      344   78    9  300  864  300  1E-
# 1966  NaN       27    9   24   86    6       58   45    6   39   44   39   05
# 1967  NaN      NaN  NaN  NaN  NaN  NaN      NaN  NaN    9  NaN  NaN  NaN  NaN
# 1968    9  58. 933   27    2  1.1  760  63. 873  1.8    7    0    0    0    0
# 1969  NaN      NaN  NaN  NaN    8  .40      NaN    8  NaN  NaN  NaN  NaN  NaN
#
#       𝜹𝑹𝑪 𝜹𝑭𝑰𝑬  𝜹𝑬𝑨  𝜹𝑬𝑷  𝜹𝑫𝑬   OP
# 0       0    0    0    0    0   44
# 1     NaN  NaN  NaN  NaN  NaN    1
# 2     NaN  NaN  NaN  NaN  NaN  NaN
# 3     0.0  19.  282  0.0  0.1   42
# 4     001  283  .45  001  201    6
# ...   ...  ...  ...  ...  ...  ...
# 1965  001  279  021  1E-  300    2
# 1966   08   69   34   05   39  NaN
# 1967  NaN  NaN  NaN  NaN  NaN  NaN
# 1968    0    0    0    0    0   43
# 1969  NaN  NaN  NaN  NaN  NaN    6
#
# [1970 rows x 19 columns]

# %% [markdown]
# # 导入配比数据
# **注意到，最后一行OP也就是过电位基本上是400左右的值，这里可以先实验一下。导入之前的配比数据来看看。**

# %%
import matplotlib.pyplot as plt
data = pd.read_excel("../数据/配比.xlsx")
plt.hist(data["Overpotential(mV)"].values)
# Out:
# (array([21., 47., 64., 75., 86., 86., 72., 25., 15.,  5.]),
#  array([392. , 399.2, 406.4, 413.6, 420.8, 428. , 435.2, 442.4, 449.6,
#         456.8, 464. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 分析数据特征，进行合并
# `其中OP这一行用于分割的都是3或者是4开头的两位数，所以我们将最后一行转换为字符串然后判断长度，
# 用于作为分割合并数据的依据。`

# %%
# 这个函数用于判断OP是否满足要求
def judget_OP_split(OP)->bool:
    """ 用于判断该OP是否用于作为分解的数字"""
    if type(OP)!=str:
        return False
    if len(OP) == 2:
        if OP[0]=="3" or OP[0]=="4":
            return True #满足要求是分割数据 true
    return False # 一个要求都不满足返回false

print(judget_OP_split("23"))
print(judget_OP_split("42"))
print(judget_OP_split(np.nan))
# Out:
# False
# True
# False

# %%
def merege_list(original, df_row):
    """ 将df_row的数据合并到original列表上"""
    # 这里需要去除空格
    original = [x.replace(" ","")+y.replace(" ","") for x, y in zip(original,df_row.values)]
    return original

# %% [markdown]
# ## 遍历数据来获取分割方法

# %%
# 备份一份数据，防止修改到原数据
split_data = train_data.copy()
split_data = split_data.fillna("")
split_data.head()
# Out:
#    VEN      𝑹𝑨𝑴   𝑨𝑵   𝑹𝑨   𝑹𝑪  𝑭𝑰𝑬   𝑬𝑨   𝑬𝑷  𝑫𝑬 𝜹𝑽𝑬𝑵 𝜹𝑹𝑨𝑴  𝜹𝑨𝑵  𝜹𝑹𝑨  𝜹𝑹𝑪  \
# 0   10  58. 693   28  1.9  1.1  737  111  1.9   8    0    0    0    0    0
# 1                       7    7  .12  .53    1
# 2                                 9    7
# 3  9.9      58.  27.  1.9  1.1  737  108  1.9  7.  0.1  0.2  0.1  0.0  0.0
# 4   38      604   93   72   72  .91  .53   07   9  201  436  201  001  001
#
#   𝜹𝑭𝑰𝑬  𝜹𝑬𝑨  𝜹𝑬𝑷  𝜹𝑫𝑬  OP
# 0    0    0    0    0  44
# 1                       1
# 2
# 3  19.  282  0.0  0.1  42
# 4  283  .45  001  201   6

# %%
for i in split_data.columns:
    print(i[0])
# Out:
# V
# 𝑹
# 𝑨
# 𝑹
# 𝑹
# 𝑭
# 𝑬
# 𝑬
# 𝑫
# 𝜹
# 𝜹
# 𝜹
# 𝜹
# 𝜹
# 𝜹
# 𝜹
# 𝜹
# 𝜹
# O

# %%
data_to_save = pd.DataFrame(columns=split_data.columns)
data_to_save
# Out:
# Empty DataFrame
# Columns: [VEN, 𝑹𝑨𝑴, 𝑨𝑵, 𝑹𝑨, 𝑹𝑪, 𝑭𝑰𝑬, 𝑬𝑨, 𝑬𝑷, 𝑫𝑬, 𝜹𝑽𝑬𝑵, 𝜹𝑹𝑨𝑴, 𝜹𝑨𝑵, 𝜹𝑹𝑨, 𝜹𝑹𝑪, 𝜹𝑭𝑰𝑬, 𝜹𝑬𝑨, 𝜹𝑬𝑷, 𝜹𝑫𝑬, OP]
# Index: []

# %%
data_to_save.columns
# Out:
# Index(['VEN', '𝑹𝑨𝑴', '𝑨𝑵', '𝑹𝑨', '𝑹𝑪', '𝑭𝑰𝑬', '𝑬𝑨', '𝑬𝑷', '𝑫𝑬', '𝜹𝑽𝑬𝑵', '𝜹𝑹𝑨𝑴',
#        '𝜹𝑨𝑵', '𝜹𝑹𝑨', '𝜹𝑹𝑪', '𝜹𝑭𝑰𝑬', '𝜹𝑬𝑨', '𝜹𝑬𝑷', '𝜹𝑫𝑬', 'OP'],
#       dtype='object')

# %%
def append_data_to_save(data_to_save, tempt_list, ):
    tempt_dic = {}
    for k,v in zip(['VEN', '𝑹𝑨𝑴', '𝑨𝑵', '𝑹𝑨', '𝑹𝑪', '𝑭𝑰𝑬', '𝑬𝑨', '𝑬𝑷', '𝑫𝑬', '𝜹𝑽𝑬𝑵', '𝜹𝑹𝑨𝑴',
                    '𝜹𝑨𝑵', '𝜹𝑹𝑨', '𝜹𝑹𝑪', '𝜹𝑭𝑰𝑬', '𝜹𝑬𝑨', '𝜹𝑬𝑷', '𝜹𝑫𝑬', 'OP'],tempt_list):
        tempt_dic[k] = v
    data_to_save.loc[data_to_save.size] = tempt_dic
    return data_to_save

# %%
data_to_save
# Out:
# Empty DataFrame
# Columns: [VEN, 𝑹𝑨𝑴, 𝑨𝑵, 𝑹𝑨, 𝑹𝑪, 𝑭𝑰𝑬, 𝑬𝑨, 𝑬𝑷, 𝑫𝑬, 𝜹𝑽𝑬𝑵, 𝜹𝑹𝑨𝑴, 𝜹𝑨𝑵, 𝜹𝑹𝑨, 𝜹𝑹𝑪, 𝜹𝑭𝑰𝑬, 𝜹𝑬𝑨, 𝜹𝑬𝑷, 𝜹𝑫𝑬, OP]
# Index: []

# %%
tempt_list = [""]*19
for index, row in split_data.iterrows():
    content = split_data.iloc[index,:] #获得这个当前的这一行内容
    try:
        content_next = split_data.iloc[index+1,:] #获得这个当前的这一行内容
    except:
        break #越界，终止
    #print(content.values)
    current_op = row['OP']
    #print(index,judget_OP_split(current_op)) 
    if judget_OP_split(content_next['OP']):
        #如果下一行是True
        print("\n\n\n")
        print(index)
        print(tempt_list)
        data_to_save = append_data_to_save(data_to_save,tempt_list)
        tempt_list = [""]*19
    else:
        tempt_list = merege_list(tempt_list, content)
# Out:
# 2
# ['10', '58.693', '28', '1.97', '1.17', '737.12', '111.53', '1.91', '8', '0', '0', '0', '0', '0', '0', '0', '0', '0', '441']
#
#
#
#
# 6
# ['9.938', '58.60471', '27.938', '1.97217', '1.17217', '737.9144', '108.531', '1.90752', '7.93', '0.120156', '0.243649', '0.120156', '0.000147', '0.000147', '19.28394', '282.4505', '0.000192', '0.120156', '426']
#
#
#
#
# 10
# ['9.969', '58.70044', '27.969', '1.97093', '1.17031', '737.8505', '110.0594', '1.90907', '7.96', '0.030039', '0.00173', '0.030039', '2.7E05', '3E-06', '16.2701', '68.24431', '2.7E05', '0.030039', '423']
#
#
#
#
# 14
# ['9.858', '58.49079', '27.858', '1.97497', '1.17497', '738.9279', '104.6523', '1.90432', '7.85', '0.263836', '0.535', '0.263836', '0.000323', '0.000323', '42.34328', '620.1988', '0.000422', '0.263836', '420']
#
#
#
#
# 18
# ['9.817', '58.08392', '27.655', '1.95537', '1.16195', '732.0017', '106.0496', '1.8894', '7.83', '0.15415', '0.522389', '0.208784', '0.000483', '0.000259', '78.1962', '342.5482', '0.000506', '0.15129', '422']
#
#
#
#
# 22
# ['9.929', '58.71004', '27.929', '1.97213', '1.17071', '738.7814', '108.1529', '1.90787', '7.92', '0.065959', '0.003799', '0.065959', '5.94E-05', '6.6E06', '35.72554', '149.8494', '5.94E-05', '0.065959', '427']
#
#
#
#
# 26
# ['9.796', '58.4025', '27.796', '1.97714', '1.17714', '739.7134', '101.6463', '1.90184', '7.79', '0.366384', '0.742945', '0.366384', '0.000449', '0.000449', '58.8013', '861.2582', '0.000586', '0.366384', '420']
#
#
#
#
# 689
# ['8.96', '57.714', '26.96', '2.004', '1.198', '753.50', '61.361', '1.871', '6.9', '0.6964', '2.0530', '0.6964', '0.0008', '0.0010', '132.22', '1638.1', '0.0011', '0.6964', '412']
#
#
#
#
# 693
# ['8.929', '57.61884', '26.929', '2.00613', '1.20071', '753.5708', '59.83286', '1.86987', '6.92', '0.723959', '2.106231', '0.723959', '0.000899', '0.001044', '133.2356', '1703.472', '0.001193', '0.723959', '410']
#
#
#
#
# 697
# ['8.817', '56.99272', '26.655', '1.98937', '1.19195', '746.7911', '57.72958', '1.8514', '6.83', '0.755856', '2.388511', '0.807574', '0.001254', '0.001187', '179.4056', '1764.134', '0.001516', '0.75332', '413']
#
#
#
#
# 701
# ['8.858', '57.39959', '26.858', '2.00897', '1.20497', '753.7173', '56.33227', '1.86632', '6.85', '0.779836', '2.158946', '0.779836', '0.000969', '0.001105', '135.5188', '1835.525', '0.001286', '0.779836', '404']
#
#
#
#
# 705
# ['8.795', '57.08048', '26.723', '2.00205', '1.20187', '750.7314', '54.74557', '1.85745', '6.80', '0.799567', '2.195603', '0.809796', '0.001056', '0.001139', '145.253', '1879.042', '0.00137', '0.799068', '402']
#
#
#
#
# 709
# ['8.683', '56.45436', '26.449', '1.98529', '1.19311', '743.9518', '52.64229', '1.83898', '6.70', '0.830383', '2.637748', '0.937254', '0.001688', '0.001361', '231.5518', '1924.261', '0.001919', '0.82518', '400']
#
#
#
#
# 712
# ['8.76', '57.096', '26.76', '2.012', '1.210', '753.91', '51.500', '1.861', '6.7', '0.8404', '2.0737', '0.8404', '0.0010', '0.0011', '138.59', '1977.5', '0.0013', '0.8404', '403']
#
#
#
#
# 716
# ['8.729', '57.00124', '26.729', '2.01413', '1.21271', '753.9836', '49.97206', '1.85987', '6.72', '0.855559', '2.0087', '0.855559', '0.001056', '0.001123', '139.5571', '2012.735', '0.001391', '0.855559', '407']
#
#
#
#
# 720
# ['8.617', '56.37512', '26.455', '1.99737', '1.20395', '747.2039', '47.86878', '1.8414', '6.63', '0.874037', '2.147733', '0.925172', '0.001393', '0.001217', '185.7738', '2041.289', '0.001676', '0.871566', '406']
#
#
#
#
# 724
# ['8.658', '56.78199', '26.658', '2.01697', '1.21697', '754.1301', '46.47147', '1.85632', '6.65', '0.883036', '1.790599', '0.883036', '0.001082', '0.001082', '141.7192', '2075.751', '0.001413', '0.883036', '418']
#
#
#
#
# 728
# ['9.369', '58.84444', '27.369', '1.98893', '1.17631', '751.8143', '81.46102', '1.89107', '7.36', '0.232839', '0.013412', '0.232839', '0.00021', '2.33E-05', '126.1132', '528.9769', '0.00021', '0.232839', '421']
#
#
#
#
# 733
# ['9.338', '58.74871', '27.338', '1.99017', '1.17817', '751.8782', '79.93259', '1.88952', '7.338', '0.285756', '0.2829', '0.285756', '0.000285', '0.000145', '127.3401', '655.7621', '0.000319', '0.285756', '421']
#
#
#
#
# 737
# ['8.835', '57.07088', '26.763', '2.00085', '1.20147', '749.8005', '56.65213', '1.85865', '6.84', '0.851546', '2.16663', '0.861798', '0.001115', '0.001164', '153.6342', '2000.236', '0.001441', '0.851044', '404']
#
#
#
#
# 792
# ['8.84', '57.210', '26.84', '2.010', '1.208', '752.90', '55.379', '1.864', '6.8', '0.8724', '2.0999', '0.8724', '0.0010', '0.0011', '145.92', '2052.1', '0.0014', '0.8724', '407']
#
#
#
#
# 796
# ['8.881', '57.61777', '27.043', '2.02969', '1.22107', '759.8323', '53.9819', '1.87954', '6.86', '0.904688', '2.337625', '0.957066', '0.001438', '0.001286', '194.1671', '2113.163', '0.001739', '0.902138', '407']
#
#
#
#
# 800
# ['8.769', '56.99164', '26.769', '2.01293', '1.21231', '753.0527', '51.87862', '1.86107', '6.76', '0.915639', '1.973822', '0.915639', '0.001125', '0.001153', '148.4057', '2152.981', '0.001474', '0.915639', '412']
#
#
#
#
# 804
# ['8.738', '56.89591', '26.738', '2.01417', '1.21417', '753.1166', '50.35019', '1.85952', '6.73', '0.931356', '1.888581', '0.931356', '0.001141', '0.001141', '149.4742', '2189.337', '0.00149', '0.931356', '414']
#
#
#
#
# 807
# ['9.4', '58.837', '27.4', '1.988', '1.176', '751.09', '82.938', '1.892', '7.4', '0.24', '0.0138', '0.24', '0.0002', '0.0000', '129.99', '545.24', '0.0002', '0.24', '427']
#
#
#
#
# 811
# ['9.369', '58.74127', '27.369', '1.98924', '1.17786', '751.1568', '81.41018', '1.89045', '7.36', '0.294839', '0.281888', '0.294839', '0.000294', '0.000147', '131.3111', '676.5476', '0.000328', '0.294839', '421']
#
#
#
#
# 815
# ['9.329', '58.61775', '27.329', '1.99084', '1.18026', '751.2393', '79.43802', '1.88845', '7.32', '0.362759', '0.600697', '0.362759', '0.00039', '0.000296', '133.0012', '839.0658', '0.000466', '0.362759', '414']
#
#
#
#
# 819
# ['9.298', '58.52202', '27.298', '1.99208', '1.18212', '751.3033', '77.90959', '1.8869', '7.29', '0.413196', '0.826785', '0.413196', '0.00046', '0.000403', '134.3017', '959.6671', '0.000567', '0.413196', '417']
#
#
#
#
# 823
# ['9.271', '58.43865', '27.271', '1.99316', '1.18374', '751.3591', '76.57838', '1.88555', '7.27', '0.455559', '1.008767', '0.455559', '0.00052', '0.00049', '135.4277', '1060.9', '0.000652', '0.455559', '413']
#
#
#
#
# 828
# ['9.231', '58.31513', '27.231', '1.99476', '1.18614', '751.4416', '74.60622', '1.88355', '7.23', '0.515639', '1.252815', '0.515639', '0.000603', '0.000611', '137.0845', '1204.36', '0.00077', '0.515639', '412']
#
#
#
#
# 831
# ['9.2', '58.219', '27.2', '1.996', '1.188', '751.50', '73.077', '1.882', '7.2', '0.56', '1.4209', '0.56', '0.0006', '0.0006', '138.35', '1310.1', '0.0008', '0.56', '415']
#
#
#
#
# 835
# ['9.169', '58.12367', '27.169', '1.99724', '1.18986', '751.5696', '71.54938', '1.88045', '7.16', '0.602439', '1.570785', '0.602439', '0.000722', '0.000774', '139.6255', '1411.35', '0.000937', '0.602439', '413']
# 57    9.858  58.49079  27.858  1.97497  1.17497  738.9279  104.6523  1.90432
# 76    9.817  58.08392  27.655  1.95537  1.16195  732.0017  106.0496   1.8894
# ...     ...       ...     ...      ...      ...       ...       ...      ...
# 9310  8.831  58.41113  26.831  2.00676  1.19014  760.7508  55.54062  1.87155
# 9329  8.871  58.53465  26.871  2.00516  1.18774  760.6683  57.51278  1.87355
# 9348  8.898  58.61802  26.898  2.00408  1.18612  760.6125  58.84399   1.8749
# 9367  8.929  58.71375  26.929  2.00284  1.18426  760.5485  60.37242  1.87645
# 9386  8.969  58.83727  26.969  2.00124  1.18186   760.466  62.34458  1.87845
#
#         𝑫𝑬      𝜹𝑽𝑬𝑵      𝜹𝑹𝑨𝑴       𝜹𝑨𝑵       𝜹𝑹𝑨       𝜹𝑹𝑪      𝜹𝑭𝑰𝑬  \
# 0        8         0         0         0         0         0         0
# 19    7.93  0.120156  0.243649  0.120156  0.000147  0.000147  19.28394
# 38    7.96  0.030039   0.00173  0.030039    2.7E05     3E-06   16.2701
# 57    7.85  0.263836     0.535  0.263836  0.000323  0.000323  42.34328
# 76    7.83   0.15415  0.522389  0.208784  0.000483  0.000259   78.1962
# ...    ...       ...       ...       ...       ...       ...       ...
# 9310  6.83  0.140439   1.33919  0.140439  0.000225  0.000506  0.598284
# 9329  6.87  0.112359  1.071427  0.112359   0.00018  0.000404   0.47866
# 9348  6.89  0.091596  0.873436  0.091596  0.000147   0.00033  0.390208
# 9367  6.92  0.065959  0.628968  0.065959  0.000106  0.000237  0.280992
# 9386  6.96  0.030039  0.286444  0.030039  4.81E-05  0.000108  0.127969
#
#            𝜹𝑬𝑨       𝜹𝑬𝑷       𝜹𝑫𝑬   OP
# 0            0         0         0  441
# 19    282.4505  0.000192  0.120156  426
# 38    68.24431    2.7E05  0.030039  423
# 57    620.1988  0.000422  0.263836  420
# 76    342.5482  0.000506   0.15129  422
# ...        ...       ...       ...  ...
# 9310   341.391  0.000351  0.140439  443
# 9329  273.1317  0.000281  0.112359  437
# 9348  222.6593  0.000229  0.091596  438
# 9367  160.3387  0.000165  0.065959  440
# 9386  73.02134  7.51E-05  0.030039  442
#
# [495 rows x 19 columns]

# %% [markdown]
# # 保存数据

# %%
data_to_save.to_csv("../数据/ManualFeature.csv",  index=None, encoding="UTF-8")

# 这一步以后还需要手动更改一些数据

# %% [markdown]
# # 导入数据进行机器学习

# %%
train_data = pd.read_csv("../数据/ManualFeature.csv", dtype="float64")
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495 entries, 0 to 494
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   VEN     495 non-null    float64
#  1   𝑹𝑨𝑴     495 non-null    float64
#  2   𝑨𝑵      495 non-null    float64
#  3   𝑹𝑨      495 non-null    float64
#  4   𝑹𝑪      495 non-null    float64
#  5   𝑭𝑰𝑬     495 non-null    float64
#  6   𝑬𝑨      495 non-null    float64
#  7   𝑬𝑷      495 non-null    float64
#  8   𝑫𝑬      495 non-null    float64
#  9   𝜹𝑽𝑬𝑵    495 non-null    float64
#  10  𝜹𝑹𝑨𝑴    495 non-null    float64
#  11  𝜹𝑨𝑵     495 non-null    float64
#  12  𝜹𝑹𝑨     495 non-null    float64
#  13  𝜹𝑹𝑪     495 non-null    float64
#  14  𝜹𝑭𝑰𝑬    495 non-null    float64
#  15  𝜹𝑬𝑨     495 non-null    float64
#  16  𝜹𝑬𝑷     495 non-null    float64
#  17  𝜹𝑫𝑬     495 non-null    float64
#  18  OP      495 non-null    float64
# dtypes: float64(19)
# memory usage: 73.6 KB

# %%
train_data.describe()
# Out:
#               VEN         𝑹𝑨𝑴          𝑨𝑵          𝑹𝑨          𝑹𝑪         𝑭𝑰𝑬  \
# count  495.000000  495.000000  495.000000  495.000000  495.000000  495.000000
# mean     9.004182   57.848251   27.012545    2.004232    1.197221  753.667563
# std      0.431100    0.787810    0.448800    0.017973    0.017244    7.068012
# min      8.000000   55.526410   25.859000    1.955370    1.161950  732.001700
# 25%      8.702000   57.254725   26.674000    1.991555    1.183780  748.654500
# 50%      9.005000   57.969190   27.027000    2.003370    1.195560  754.385100
# 75%      9.318000   58.484055   27.341000    2.016735    1.208790  759.045350
# max     10.000000   59.462840   28.151000    2.058710    1.246890  770.432600
#
#                𝑬𝑨          𝑬𝑷          𝑫𝑬        𝜹𝑽𝑬𝑵        𝜹𝑹𝑨𝑴         𝜹𝑨𝑵  \
# count  495.000000  495.000000  495.000000  495.000000  495.000000  495.000000
# mean    63.354588    1.874157    6.995541    0.486834    1.511686    0.502523
# std     20.794945    0.019611    0.430128    0.237819    0.720971    0.241048
# min     14.569000    1.817560    6.000000    0.000000    0.000000    0.000000
# 25%     48.390710    1.860160    6.690000    0.294997    0.926877    0.307239
# 50%     63.545000    1.875030    7.000000    0.455732    1.693920    0.483036
# 75%     78.365145    1.889010    7.300000    0.662111    2.094672    0.683394
# max    111.530000    1.927020    8.000000    0.997291    2.923570    1.066803
#
#                  𝜹𝑹𝑨           𝜹𝑹𝑪        𝜹𝑭𝑰𝑬          𝜹𝑬𝑨            𝜹𝑬𝑷  \
# count     495.000000  4.950000e+02  495.000000   495.000000     495.000000
# mean     1090.909781  2.723232e+04  109.733485  1139.994581    1090.909963
# std     17144.946987  4.191569e+05   53.966876   558.700739   17144.946975
# min         0.000000  0.000000e+00    0.000000     0.000000       0.000000
# 25%         0.000440  4.690000e-04   67.515960   689.124850       0.000584
# 50%         0.000668  8.000000e-04  122.486000  1079.370000       0.000881
# 75%         0.000956  1.001000e-03  145.454600  1549.771000       0.001198
# max    270000.000000  6.600000e+06  255.044400  2342.791000  270000.000000
#
#               𝜹𝑫𝑬          OP
# count  495.000000  495.000000
# mean     0.486059  423.771717
# std      0.237746   14.530939
# min      0.000000  392.000000
# 25%      0.294839  413.000000
# 50%      0.455559  424.000000
# 75%      0.661942  435.000000
# max      0.996781  464.000000

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import numpy as np
import pandas as pd
from sklearn.utils import shuffle as reset
def train_test_split(data, test_size=0.3, shuffle=True, random_state=None):
    '''Split DataFrame into random train and test subsets
    
    Parameters
    ----------
    data : pandas dataframe, need to split dataset.
    
    test_size : float
        If float, should be between 0.0 and 1.0 and represent the
        proportion of the dataset to include in the train split.
        
    random_state : int, RandomState instance or None, optional (default=None)
        If int, random_state is the seed used by the random number generator;
        If RandomState instance, random_state is the random number generator;
        If None, the random number generator is the RandomState instance used
        by `np.random`.
        
    shuffle : boolean, optional (default=None)
        Whether or not to shuffle the data before splitting. If shuffle=False
        then stratify must be None.
    '''

    if shuffle:
        data = reset(data, random_state=random_state)
	
    train = data[int(len(data)*test_size):].reset_index(drop = True)
    test  = data[:int(len(data)*test_size)].reset_index(drop = True)
    
    return train, test

# %%
train , test = train_test_split(train_data, test_size=0.3)

# %%
label = "OP"
save = "My Model Save Path"

# %%
predictor = TabularPredictor(label=label , path=save).fit(train)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="My Model Save Path"
# Beginning AutoGluon training ...
# AutoGluon will save models to "My Model Save Path\"
# AutoGluon Version:  0.4.0
# Python Version:     3.9.7
# Operating System:   Windows
# Train Data Rows:    347
# Train Data Columns: 18
# Label Column: OP
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (462.0, 392.0, 423.92219, 14.28902)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    1993.37 MB
# 	Train Data (Original)  Memory Usage: 0.05 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 18 | ['VEN', '𝑹𝑨𝑴', '𝑨𝑵', '𝑹𝑨', '𝑹𝑪', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 18 | ['VEN', '𝑹𝑨𝑴', '𝑨𝑵', '𝑹𝑨', '𝑹𝑪', ...]
# 	0.1s = Fit runtime
# 	18 features in original data used to generate 18 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.05 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 277, Val Rows: 70
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-9.3001	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-9.0293	 = Validation score   (root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	-6.2039	 = Validation score   (root_mean_squared_error)
# 	0.55s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ...
# [1000]	valid_set's rmse: 6.22812
# 	-6.52	 = Validation score   (root_mean_squared_error)
# 	0.43s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-6.3767	 = Validation score   (root_mean_squared_error)
# 	0.89s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-6.2422	 = Validation score   (root_mean_squared_error)
# 	6.17s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-6.3828	 = Validation score   (root_mean_squared_error)
# 	0.55s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-7.7727	 = Validation score   (root_mean_squared_error)
# 	0.81s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-6.3485	 = Validation score   (root_mean_squared_error)
# 	2.48s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-7.1942	 = Validation score   (root_mean_squared_error)
# 	2.7s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	-6.4028	 = Validation score   (root_mean_squared_error)
# 	0.91s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-6.0694	 = Validation score   (root_mean_squared_error)
# 	0.38s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 16.89s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("My Model Save Path\")

# %%
test_nolabel = test.drop(columns = [label])
test_nolabel.head()
# Out:
#      VEN       𝑹𝑨𝑴      𝑨𝑵       𝑹𝑨       𝑹𝑪       𝑭𝑰𝑬         𝑬𝑨       𝑬𝑷  \
# 0  9.573  58.36617  27.573  1.98410  1.18072  744.3306   90.97291  1.89461
# 1  8.733  57.33974  26.733  2.01299  1.20757  756.0538   50.32999  1.86203
# 2  8.683  56.45436  26.449  1.98529  1.19311  743.9518   52.64229  1.83898
# 3  9.917  59.27084  28.151  2.00271  1.19089  750.1630  102.71810  1.92702
# 4  8.400  56.41400  26.400  2.02600  1.22600  757.3900   33.96200  1.84600
#
#      𝑫𝑬      𝜹𝑽𝑬𝑵      𝜹𝑹𝑨𝑴       𝜹𝑨𝑵       𝜹𝑹𝑨       𝜹𝑹𝑪      𝜹𝑭𝑰𝑬  \
# 0  7.57  0.502671  0.949248  0.502671  0.000585  0.000534  122.4860
# 1  6.73  0.657711  2.223616  0.657711  0.000836  0.001056  108.3319
# 2  6.70  0.830383  2.637748  0.937254  0.001688  0.001361  231.5518
# 3  7.89  0.326621  1.132214  0.442423  0.001031  0.000560  166.1600
# 4  6.40  0.640000  1.297700  0.640000  0.000700  0.000700  102.7100
#
#          𝜹𝑬𝑨       𝜹𝑬𝑷       𝜹𝑫𝑬
# 0  1174.0220  0.000741  0.502671
# 1  1551.9660  0.001130  0.657711
# 2  1924.2610  0.001919  0.825180
# 3   726.5639  0.001078  0.320601
# 4  1504.4000  0.001000  0.640000

# %%
train_nolabel = train.drop(columns = [label])
train_nolabel.head()
# Out:
#      VEN       𝑹𝑨𝑴      𝑨𝑵       𝑹𝑨       𝑹𝑪       𝑭𝑰𝑬        𝑬𝑨       𝑬𝑷  \
# 0  9.334  58.09216  27.406  2.00208  1.19684  750.1031  77.83708  1.89042
# 1  9.717  59.31884  27.951  2.00871  1.19289  754.8176  93.18531  1.92102
# 2  8.681  57.66577  26.843  2.03569  1.22307  764.4869  44.44910  1.87354
# 3  9.083  57.68956  26.849  1.96929  1.16911  743.1262  72.36389  1.85898
# 4  9.165  58.79832  27.237  2.00515  1.18853  758.2781  70.10987  1.88935
#
#      𝑫𝑬      𝜹𝑽𝑬𝑵      𝜹𝑹𝑨𝑴       𝜹𝑨𝑵       𝜹𝑹𝑨       𝜹𝑹𝑪      𝜹𝑭𝑰𝑬  \
# 0  7.32  0.814938  1.813736  0.825519  0.001052  0.001024  157.9735
# 1  7.69  0.402372  1.159957  0.516958  0.001096  0.000554  222.5513
# 2  6.66  0.585477  2.499866  0.637271  0.001085  0.001142  133.3346
# 3  7.10  0.431599  1.588088  0.540905  0.001144  0.000711  217.9641
# 4  7.15  0.317764  0.904386  0.328248  0.000427  0.000398  108.1383
#
#          𝜹𝑬𝑨       𝜹𝑬𝑷       𝜹𝑫𝑬
# 0  1910.1610  0.001344  0.814405
# 1   897.6460  0.001126  0.396488
# 2  1370.8930  0.001315  0.582991
# 3   973.8917  0.001198  0.426127
# 4   737.1932  0.000516  0.317242

# %%
y_test = test[label]

# %%
y_train = train[label]

# %%
y_test.astype("float32")
# Out:
# 0      410.0
# 1      422.0
# 2      400.0
# 3      425.0
# 4      435.0
#        ...
# 143    432.0
# 144    440.0
# 145    426.0
# 146    404.0
# 147    413.0
# Name: OP, Length: 148, dtype: float32

# %% [markdown]
# # 导入模型

# %% [markdown]
# - 各个指标

# %%
predictor = TabularPredictor.load(save)
y_pred = predictor.predict(test_nolabel)
y_pred_train = predictor.predict(train_nolabel)
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: root_mean_squared_error on test data: -6.960705332838512
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -6.960705332838512,
#     "mean_squared_error": -48.4514187306065,
#     "mean_absolute_error": -5.263541556693412,
#     "r2": 0.7868116241443166,
#     "pearsonr": 0.8908419015099588,
#     "median_absolute_error": -4.423309326171875
# }

# %% [markdown]
# - 各个模型的表现

# %%
predictor_leaderboard = predictor.leaderboard(test,silent=True)
predictor_leaderboard = predictor_leaderboard.set_index(predictor_leaderboard ["model"])

# %%
predictor_leaderboard.loc[:,"score_val"] = -predictor_leaderboard.loc[:,"score_val"]
predictor_leaderboard.loc[:,"score_test"] = -predictor_leaderboard.loc[:,"score_test"]
predictor_leaderboard
# Out:
#                                    model  score_test  score_val  \
# model
# CatBoost                        CatBoost    6.959249   6.242223
# WeightedEnsemble_L2  WeightedEnsemble_L2    6.960705   6.069430
# LightGBMXT                    LightGBMXT    7.002892   6.203874
# ExtraTreesMSE              ExtraTreesMSE    7.033519   6.382754
# LightGBM                        LightGBM    7.186708   6.520008
# RandomForestMSE          RandomForestMSE    7.214493   6.376728
# XGBoost                          XGBoost    7.417596   6.348549
# LightGBMLarge              LightGBMLarge    7.425559   6.402824
# NeuralNetTorch            NeuralNetTorch    7.624345   7.194212
# NeuralNetFastAI          NeuralNetFastAI    8.484130   7.772712
# KNeighborsUnif            KNeighborsUnif    9.287991   9.300107
# KNeighborsDist            KNeighborsDist    9.463783   9.029339
#
#                      pred_time_test  pred_time_val   fit_time  \
# model
# CatBoost                   0.003987       0.002994   6.168220
# WeightedEnsemble_L2        0.104719       0.034868  13.190634
# LightGBMXT                 0.020945       0.004985   0.553562
# ExtraTreesMSE              0.072805       0.055396   0.550649
# LightGBM                   0.006981       0.004986   0.433842
# RandomForestMSE            0.120679       0.073804   0.885538
# XGBoost                    0.023939       0.009938   2.479114
# LightGBMLarge              0.019948       0.004987   0.911621
# NeuralNetTorch             0.022938       0.010970   2.699592
# NeuralNetFastAI            0.044879       0.023937   0.807807
# KNeighborsUnif             0.012965       0.017956   0.008977
# KNeighborsDist             0.017952       0.018945   0.015959
#
#                      pred_time_test_marginal  pred_time_val_marginal  \
# model
# CatBoost                            0.003987                0.002994
# WeightedEnsemble_L2                 0.012962                0.000996
# LightGBMXT                          0.020945                0.004985
# ExtraTreesMSE                       0.072805                0.055396
# LightGBM                            0.006981                0.004986
# RandomForestMSE                     0.120679                0.073804
# XGBoost                             0.023939                0.009938
# LightGBMLarge                       0.019948                0.004987
# NeuralNetTorch                      0.022938                0.010970
# NeuralNetFastAI                     0.044879                0.023937
# KNeighborsUnif                      0.012965                0.017956
# KNeighborsDist                      0.017952                0.018945
#
#                      fit_time_marginal  stack_level  can_infer  fit_order
# model
# CatBoost                      6.168220            1       True          6
# WeightedEnsemble_L2           0.378525            2       True         12
# LightGBMXT                    0.553562            1       True          3
# ExtraTreesMSE                 0.550649            1       True          7
# LightGBM                      0.433842            1       True          4
# RandomForestMSE               0.885538            1       True          5
# XGBoost                       2.479114            1       True          9
# LightGBMLarge                 0.911621            1       True         11
# NeuralNetTorch                2.699592            1       True         10
# NeuralNetFastAI               0.807807            1       True          8
# KNeighborsUnif                0.008977            1       True          1
# KNeighborsDist                0.015959            1       True          2

# %%
predictor_leaderboard.plot.bar(figsize=(20,12))
plt.savefig("所有指标.png", dpi=300)

# %%
predictor_leaderboard.columns
# Out:
# Index(['model', 'score_test', 'score_val', 'pred_time_test', 'pred_time_val',
#        'fit_time', 'pred_time_test_marginal', 'pred_time_val_marginal',
#        'fit_time_marginal', 'stack_level', 'can_infer', 'fit_order'],
#       dtype='object')

# %%
predicitions.loc[:,"score_test"] = -predicitions.loc[:,"score_test"]

# %%
predicitions = predictor_leaderboard.drop(columns = ['pred_time_test', 'pred_time_val',
       'fit_time','pred_time_test_marginal', 'pred_time_val_marginal',
       'fit_time_marginal', 'stack_level', 'can_infer', 'fit_order'] )
predicitions
# Out:
#                                    model  score_test  score_val
# model
# CatBoost                        CatBoost    6.959249   6.242223
# WeightedEnsemble_L2  WeightedEnsemble_L2    6.960705   6.069430
# LightGBMXT                    LightGBMXT    7.002892   6.203874
# ExtraTreesMSE              ExtraTreesMSE    7.033519   6.382754
# LightGBM                        LightGBM    7.186708   6.520008
# RandomForestMSE          RandomForestMSE    7.214493   6.376728
# XGBoost                          XGBoost    7.417596   6.348549
# LightGBMLarge              LightGBMLarge    7.425559   6.402824
# NeuralNetTorch            NeuralNetTorch    7.624345   7.194212
# NeuralNetFastAI          NeuralNetFastAI    8.484130   7.772712
# KNeighborsUnif            KNeighborsUnif    9.287991   9.300107
# KNeighborsDist            KNeighborsDist    9.463783   9.029339

# %%
predicitions.loc[:,"score_val"] = -predicitions.loc[:,"score_val"]
predicitions.loc[:,"score_test"] = -predicitions.loc[:,"score_test"]

# %%
predicitions.plot.bar(figsize=(20,12))
plt.ylabel("RMSE")
plt.savefig("测试效果.png", dpi=300)

# %%
[i for i in predicitions["model"].values]
# Out:
# ['CatBoost',
#  'WeightedEnsemble_L2',
#  'LightGBMXT',
#  'ExtraTreesMSE',
#  'LightGBM',
#  'RandomForestMSE',
#  'XGBoost',
#  'LightGBMLarge',
#  'NeuralNetTorch',
#  'NeuralNetFastAI',
#  'KNeighborsUnif',
#  'KNeighborsDist']

# %%
train["OP"].values
# Out:
# array([403., 429., 436., 417., 429., 416., 431., 430., 413., 430., 420.,
#        427., 444., 415., 410., 427., 431., 421., 454., 435., 423., 394.,
#        431., 432., 429., 399., 422., 433., 404., 418., 436., 405., 415.,
#        424., 392., 426., 411., 409., 414., 412., 427., 402., 413., 405.,
#        437., 424., 399., 442., 424., 420., 409., 448., 434., 425., 402.,
#        435., 462., 441., 421., 422., 411., 453., 417., 432., 432., 421.,
#        409., 437., 425., 407., 424., 440., 426., 433., 455., 405., 406.,
#        411., 424., 442., 430., 422., 415., 443., 412., 398., 413., 404.,
#        457., 418., 418., 427., 453., 401., 421., 436., 424., 418., 406.,
#        415., 441., 409., 441., 429., 438., 395., 435., 421., 422., 422.,
#        401., 414., 422., 405., 421., 436., 442., 452., 446., 440., 415.,
#        414., 415., 416., 408., 431., 438., 429., 417., 416., 441., 426.,
#        404., 441., 436., 443., 427., 422., 412., 428., 443., 440., 417.,
#        401., 418., 424., 412., 416., 414., 437., 426., 429., 411., 424.,
#        424., 425., 442., 418., 431., 415., 401., 427., 433., 453., 428.,
#        433., 436., 431., 421., 430., 443., 422., 415., 419., 433., 413.,
#        422., 450., 427., 430., 418., 398., 398., 442., 413., 436., 430.,
#        431., 448., 429., 432., 414., 443., 417., 432., 444., 449., 436.,
#        408., 440., 418., 401., 410., 433., 416., 420., 435., 445., 427.,
#        425., 438., 412., 438., 429., 398., 439., 427., 421., 405., 414.,
#        421., 448., 433., 420., 427., 430., 421., 438., 431., 441., 413.,
#        437., 439., 414., 403., 406., 421., 416., 409., 440., 438., 417.,
#        411., 439., 430., 398., 404., 415., 415., 427., 427., 435., 412.,
#        399., 418., 417., 421., 429., 432., 427., 397., 442., 435., 438.,
#        399., 442., 432., 434., 435., 452., 442., 438., 423., 430., 428.,
#        403., 436., 443., 397., 423., 404., 410., 403., 424., 428., 447.,
#        393., 436., 415., 408., 440., 415., 412., 420., 412., 419., 431.,
#        438., 403., 441., 444., 405., 419., 407., 412., 431., 436., 439.,
#        452., 398., 429., 409., 407., 462., 431., 400., 430., 400., 408.,
#        433., 420., 405., 446., 426., 429., 452., 421., 424., 421., 413.,
#        429., 439., 438., 421., 414., 407., 415., 412., 438., 421., 432.,
#        422., 415., 406., 414., 412., 436.])

# %%
test["OP"].values
# Out:
# array([410., 422., 400., 425., 435., 437., 426., 396., 404., 395., 445.,
#        409., 440., 420., 445., 427., 431., 397., 402., 425., 455., 428.,
#        428., 420., 423., 419., 407., 447., 427., 432., 407., 407., 442.,
#        438., 435., 436., 405., 432., 411., 419., 431., 412., 437., 415.,
#        403., 421., 417., 411., 402., 434., 435., 421., 417., 420., 456.,
#        404., 438., 419., 407., 438., 416., 416., 423., 426., 416., 447.,
#        405., 427., 411., 403., 406., 437., 419., 439., 429., 412., 441.,
#        459., 418., 452., 409., 421., 436., 432., 415., 399., 434., 413.,
#        453., 427., 427., 420., 408., 431., 435., 429., 420., 432., 418.,
#        432., 409., 448., 408., 417., 405., 396., 443., 406., 447., 414.,
#        413., 409., 435., 421., 404., 423., 442., 452., 411., 410., 438.,
#        429., 442., 433., 435., 426., 402., 410., 421., 439., 414., 421.,
#        407., 412., 445., 401., 427., 438., 406., 464., 427., 434., 427.,
#        432., 440., 426., 404., 413.])

# %% [markdown]
# # 预测·结果图

# %%
x = np.arange(400,460,0.01)
y = x
plt.figure(figsize=(12,8))
plt.plot(x,y,'r--')
p1 = plt.scatter(y_pred.values,y_test.values)
p2 = plt.scatter(train["OP"].values, y_pred_train)
plt.legend([p1, p2],[ "test", "train"])
plt.xlabel("Predict OP/(mv)")
plt.ylabel("True OP/(mv)")
plt.title("Oover Potential Prediction Graph")
plt.savefig("预测结果.png", dpi=300)

# %% [markdown]
# # 绘图

# %% [markdown]
# ##  各个模型的预测效果图

# %%
predicitions = pd.DataFrame(predicitions, index=[i for i in predicitions["model"].values])
predicitions
# Out:
#                                    model    score_test  score_val
# ExtraTreesMSE              ExtraTreesMSE  6.019490e+00   5.773924
# LightGBMXT                    LightGBMXT  6.274595e+00   6.251878
# LightGBMLarge              LightGBMLarge  6.392802e+00   7.034210
# CatBoost                        CatBoost  6.435967e+00   6.218969
# RandomForestMSE          RandomForestMSE  6.480979e+00   6.072065
# WeightedEnsemble_L2  WeightedEnsemble_L2  6.483472e+00   5.444529
# LightGBM                        LightGBM  6.497182e+00   6.273338
# NeuralNetTorch            NeuralNetTorch  7.317346e+00   5.603535
# XGBoost                          XGBoost  7.976532e+00   6.959762
# KNeighborsDist            KNeighborsDist  8.714210e+00   7.082393
# KNeighborsUnif            KNeighborsUnif  9.099139e+00   7.666700
# NeuralNetFastAI          NeuralNetFastAI  1.869795e+07   6.479749

# %%
predicitions = pd.DataFrame(predicitions, index=[i for i in predicitions["model"].values])
predicitions.plot.bar()#(figsize=(20,12))#, index=[i for i in predicitions["model"].values])
plt.ylabel("RMSE")
plt.title("RMSE for both test and validation dataset")
# Out:
# Text(0.5, 1.0, 'RMSE for both test and validation dataset')

# %%
data.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 相关性图

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import palettable
import matplotlib.pyplot as plt
# 支持中文
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
data = pd.read_csv("../数据/ManualFeature.csv", dtype="float32")
data.columns = ['VEN', 'RAM', 'AN', 'RA', 'RC', 'FIE', 'EA', 'EP', 'DE', 'δVEN', 'δRAM', 'δAN','δRA', 'δRC', 'δFIE', 'δEA', 'δEP', 'δDE', 'OP']
# corr函数计算相关性矩阵(correlation matrix)
dcorr = data.corr()#(method='pearson')#默认为'pearson'检验，可选'kendall','spearman'
plt.figure(figsize=(12, 8),dpi=100)
sns.heatmap(data=dcorr,
            vmax=0.3, 
            cmap=palettable.cmocean.diverging.Balance_10.mpl_colors,
            annot=True,
            fmt=".2f",
            annot_kws={'size':8,'weight':'normal', 'color':'#253D24'},
            mask=np.triu(np.ones_like(dcorr,dtype=np.bool)),#显示对脚线下面部分图
            square=True, linewidths=.5,#每个方格外框显示，外框宽度设置
            cbar_kws={"shrink": .5}
           )
plt.savefig("皮尔逊 热力图.png",dpi=300)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_11696\2714896359.py:22: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.triu(np.ones_like(dcorr,dtype=np.bool)),#显示对脚线下面部分图

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495 entries, 0 to 494
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   VEN     495 non-null    float32
#  1   RAM     495 non-null    float32
#  2   AN      495 non-null    float32
#  3   RA      495 non-null    float32
#  4   RC      495 non-null    float32
#  5   FIE     495 non-null    float32
#  6   EA      495 non-null    float32
#  7   EP      495 non-null    float32
#  8   DE      495 non-null    float32
#  9   δVEN    495 non-null    float32
#  10  δRAM    495 non-null    float32
#  11  δAN     495 non-null    float32
#  12  δRA     495 non-null    float32
#  13  δRC     495 non-null    float32
#  14  δFIE    495 non-null    float32
#  15  δEA     495 non-null    float32
#  16  δEP     495 non-null    float32
#  17  δDE     495 non-null    float32
#  18  OP      495 non-null    float32
# dtypes: float32(19)
# memory usage: 36.9 KB

# %%
data.corr()
# Out:
#            VEN       RAM        AN        RA        RC       FIE        EA  \
# VEN   1.000000  0.807938  0.980685 -0.774693 -0.830930 -0.711102  0.996119
# RAM   0.807938  1.000000  0.846879 -0.486207 -0.737355 -0.216172  0.785439
# AN    0.980685  0.846879  1.000000 -0.636795 -0.731364 -0.580278  0.959770
# RA   -0.774693 -0.486207 -0.636795  1.000000  0.936632  0.901874 -0.827333
# RC   -0.830930 -0.737355 -0.731364  0.936632  1.000000  0.715017 -0.868513
# FIE  -0.711102 -0.216172 -0.580278  0.901874  0.715017  1.000000 -0.757136
# EA    0.996119  0.785439  0.959770 -0.827333 -0.868513 -0.757136  1.000000
# EP    0.918018  0.911602  0.973869 -0.483263 -0.646768 -0.381434  0.882761
# DE    0.999446  0.801257  0.976001 -0.787325 -0.839084 -0.723614  0.997413
# DE    0.410971 -0.010303  0.074034  0.001937 -0.396956
# δVEN  0.681502  0.999762 -0.122463  0.999983 -0.700499
# δRAM  0.143345  0.595094 -0.133529  0.585325 -0.124483
# δAN   0.731144  0.991113 -0.124972  0.992371 -0.695462
# δRA  -0.110419 -0.122305  1.000000 -0.122293  0.036103
# δRC  -0.088266 -0.114964 -0.004142 -0.114610  0.082410
# δFIE  1.000000  0.665796 -0.110419  0.678733 -0.724730
# δEA   0.665796  1.000000 -0.122305  0.999832 -0.693379
# δEP  -0.110419 -0.122305  1.000000 -0.122293  0.036103
# δDE   0.678733  0.999832 -0.122293  1.000000 -0.700456
# OP   -0.724730 -0.693379  0.036103 -0.700456  1.000000

# %%
plt.figure(figsize=(10, 10),dpi=100)
sns.clustermap(data=dcorr,
               vmax=0.3,
               annot=True,
               cmap=palettable.cmocean.diverging.Balance_10.mpl_colors,
               linewidths=.75,
               annot_kws={'size':8,'weight':'normal', 'color':'#253D24'},
               mask=np.triu(np.ones_like(dcorr,dtype=np.bool)),#显示对脚线下面部分图
               square=True,
               cbar_kws={"shrink": .5}
                              
              )
plt.savefig("皮尔逊 聚类图.png",dpi=300)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_11696\2003944317.py:8: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.triu(np.ones_like(dcorr,dtype=np.bool)),#显示对脚线下面部分图

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib as mpl
 
import numpy as np
models = np.array(['LightGBM DSTL', 'CatBoost DSTL', 'WeightedEnsemble L2 DSTL'])
score_tests = np.array([0.997803,0.998342,0.999929])
score_val = np.array([0.9976,0.9980,1.0000])
pred_time_test = np.array([3.031554,0.186510,9.393527])
pred_time_val = np.array([0.014961,0.003990,0.077688])
fit_time = np.array([2.932168,10.305332,7.537612])
plt.figure(figsize=(12,8))
mpl.rcParams['font.sans-serif'] = ['Times New Roman']  
mpl.rcParams['font.weight'] = 'bold'  
mpl.rcParams['font.size'] = 12 
#for model ,test ,val  = in zip(models,score_tests,score_val):
plt.barh(np.arange(0.1,0.6*(3),0.6),score_tests,height=0.07,label='score_test',color = np.array([(1,86,153)])/255 )
plt.barh(np.arange(0.1,0.6*(3),0.6)+0.072,score_val,height=0.07,label='score_val',color = np.array([(249,192,15)])/255 )
plt.barh(np.arange(0.1,0.6*(3),0.6)+0.072+0.072,pred_time_test,height=0.07,label='pred_time_test',color = np.array([(243,118,74)])/255 )
plt.barh(np.arange(0.1,0.6*(3),0.6)+0.072+0.072+0.072,pred_time_val,height=0.07,label='pred_time_val',color = np.array([(95,199,202)])/255 )
plt.barh(np.arange(0.1,0.6*(3),0.6)+0.072*4,fit_time,height=0.1,label='fit_time',color = np.array([(78,89,109)])/255 )


plt.legend(frameon=False,loc='upper right')
plt.ylim(0,2.8)
plt.xticks(np.arange(0,12,2))
plt.yticks(np.arange(0.2,0.6*(4),0.6), models, fontsize=12)
plt.ylabel('Models', fontsize=12,fontweight='bold')
plt.xlabel('Score', fontsize=12,fontweight='bold')


plt.savefig('./蒸馏模型core.png', bbox_inches='tight', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [220], in <cell line: 28>()
#      26 plt.ylim(0,2.8)
#      27 plt.xticks(np.arange(0,12,2))
# ---> 28 plt.yticks(np.arange(0.2,0.6*(4),0.6), models, fontsize=12)
#      29 plt.ylabel('Models', fontsize=12,fontweight='bold')
#      30 plt.xlabel('Score', fontsize=12,fontweight='bold')
#
# File E:\Anaconda\envs\pytorch\lib\site-packages\matplotlib\pyplot.py:1855, in yticks(ticks, labels, **kwargs)
#    1853         l.update(kwargs)
#    1854 else:
# -> 1855     labels = ax.set_yticklabels(labels, **kwargs)
#    1857 return locs, labels
#
# File E:\Anaconda\envs\pytorch\lib\site-packages\matplotlib\axes\_base.py:75, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      74 def wrapper(self, *args, **kwargs):
# ---> 75     return get_method(self)(*args, **kwargs)
#
# File E:\Anaconda\envs\pytorch\lib\site-packages\matplotlib\axis.py:1798, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796 if fontdict is not None:
#    1797     kwargs.update(fontdict)
# -> 1798 return self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File E:\Anaconda\envs\pytorch\lib\site-packages\matplotlib\axis.py:1720, in Axis.set_ticklabels(self, ticklabels, minor, **kwargs)
#    1716 if isinstance(locator, mticker.FixedLocator):
#    1717     # Passing [] as a list of ticklabels is often used as a way to
#    1718     # remove all tick labels, so only error for > 0 ticklabels
#    1719     if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1720         raise ValueError(
#    1721             "The number of FixedLocator locations"
#    1722             f" ({len(locator.locs)}), usually from a call to"
#    1723             " set_ticks, does not match"
#    1724             f" the number of ticklabels ({len(ticklabels)}).")
#    1725     tickd = {loc: lab for loc, lab in zip(locator.locs, ticklabels)}
#    1726     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (4), usually from a call to set_ticks, does not match the number of ticklabels (3).

# %% [markdown]
# # 下面是无关内容

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_pred,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [194], in <cell line: 3>()
#       1 from sklearn.metrics import confusion_matrix
# ----> 3 confusion_matrix(y_pred,y_test)
#
# File E:\Anaconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:307, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     222 def confusion_matrix(
#     223     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     224 ):
#     225     """Compute confusion matrix to evaluate the accuracy of a classification.
#     226
#     227     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# File E:\Anaconda\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:93, in _check_targets(y_true, y_pred)
#      90     y_type = {"multiclass"}
#      92 if len(y_type) > 1:
# ---> 93     raise ValueError(
#      94         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95             type_true, type_pred
#      96         )
#      97     )
#      99 # We can't have more than one value on y_type => The set is no more needed
#     100 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of continuous and multiclass targets

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x = np.arange(1,20,0.03)

# %%
y =  np.sin(x) + np.sin((10.0 / 3.0) * x)

# %%
plt.scatter(x,y)

# %%
x = x.reshape(-1,1)
y = y.reshape(-1,1)

# %%
data = np.hstack((x,y))
data
# Out:
# array([[ 1.        ,  0.65090302],
#        [ 1.03      ,  0.5696792 ],
#        [ 1.06      ,  0.49055767],
#        ...,
#        [19.93      ,  0.43831963],
#        [19.96      ,  0.36480509],
#        [19.99      ,  0.29579079]])

# %%
df = pd.DataFrame(data,columns=['X','Y']) # 将第一维度数据转为为行，第二维度数据转化为列，即 3 行 2 列，并设置列标签
print(df)
# Out:
#          X         Y
# 0     1.00  0.650903
# 1     1.03  0.569679
# 2     1.06  0.490558
# 3     1.09  0.414466
# 4     1.12  0.342294
# ..     ...       ...
# 629  19.87  0.595368
# 630  19.90  0.515475
# 631  19.93  0.438320
# 632  19.96  0.364805
# 633  19.99  0.295791
#
# [634 rows x 2 columns]

# %%
df.to_csv("X Y.csv")

# %%
from autogluon.tabular import TabularPredictor
predictor = TabularPredictor(label="Y").fit(train_data="X Y.csv")
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20220807_050920\"
# Loaded data from: X Y.csv | Columns = 3 / 3 | Rows = 634 -> 634
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20220807_050920\"
# AutoGluon Version:  0.4.0
# Python Version:     3.9.7
# Operating System:   Windows
# Train Data Rows:    634
# Train Data Columns: 2
# Label Column: Y
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.9883004507818312, -1.9879101200641944, 0.0042, 0.99734)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    2497.24 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 1 | ['X']
# 		('int', [])   : 1 | ['Unnamed: 0']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 1 | ['X']
# 		('int', [])   : 1 | ['Unnamed: 0']
# 	0.0s = Fit runtime
# 	2 features in original data used to generate 2 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.04s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 507, Val Rows: 127
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-0.0569	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-0.0355	 = Validation score   (root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 0.325058
# [2000]	valid_set's rmse: 0.190282
# [3000]	valid_set's rmse: 0.148203
# [4000]	valid_set's rmse: 0.134217
# [5000]	valid_set's rmse: 0.130171
# [6000]	valid_set's rmse: 0.128565
# [7000]	valid_set's rmse: 0.128079
# [8000]	valid_set's rmse: 0.127687
# [9000]	valid_set's rmse: 0.127539
# [10000]	valid_set's rmse: 0.127671
# 	-0.1275	 = Validation score   (root_mean_squared_error)
# 	2.14s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM ...
# [1000]	valid_set's rmse: 0.133206
# [2000]	valid_set's rmse: 0.132665
# 	-0.1327	 = Validation score   (root_mean_squared_error)
# 	0.93s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-0.039	 = Validation score   (root_mean_squared_error)
# 	0.35s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-0.077	 = Validation score   (root_mean_squared_error)
# 	6.44s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-0.0164	 = Validation score   (root_mean_squared_error)
# 	0.31s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-0.9961	 = Validation score   (root_mean_squared_error)
# 	1.23s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-0.0991	 = Validation score   (root_mean_squared_error)
# 	0.35s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-0.42	 = Validation score   (root_mean_squared_error)
# 	24.63s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	-0.1151	 = Validation score   (root_mean_squared_error)
# 	0.69s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.0158	 = Validation score   (root_mean_squared_error)
# 	0.34s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 38.84s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20220807_050920\")

# %%
data = df.drop(columns = ["Y"])

# %%
data
# Out:
#          X
# 0     1.00
# 1     1.03
# 2     1.06
# 3     1.09
# 4     1.12
# ..     ...
# 629  19.87
# 630  19.90
# 631  19.93
# 632  19.96
# 633  19.99
#
# [634 rows x 1 columns]

# %%
df = pd.read_csv("X Y.csv")
data = df.drop(columns = ["Y"])

# %%
y_pred = predictor.predict(df)

# %%
y_pred
# Out:
# 0      0.582562
# 1      0.533796
# 2      0.477322
# 3      0.404002
# 4      0.345042
#          ...
# 629    0.587919
# 630    0.515062
# 631    0.439358
# 632    0.378641
# 633    0.339875
# Name: Y, Length: 634, dtype: float32

# %%
plt.scatter(x[::2],y[::2],s=100,color = "black")
plt.plot(x,y_pred,color="red")

# %%
y_pred = pd.DataFrame(y_pred)
y = pd.DataFrame(y)

# %%
y_pred
# Out:
#               Y
# 0     18.460981
# 1     19.335226
# 2     20.311134
# 3     21.050087
# 4     21.579062
# ..          ...
# 185  394.276001
# 186  399.773438
# 187  404.378052
# 188  408.674103
# 189  411.903473
#
# [190 rows x 1 columns]

# %%
np.sum(np.square(y_pred.values-y.values))/len(y_pred)
# Out:
# 0.24108950489164704

# %% [markdown]
# # 二元函数

# %%
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

figure = plt.figure()
ax = Axes3D(figure)#设置图像为三维格式
X = np.arange(-10,10,0.1)
Y = np.arange(-10,10,0.1)#X,Y的范围
X,Y = np.meshgrid(X,Y)#绘制网格
Z=(np.sin(X)*np.sin(Y))/(X*Y)#f(x,y)=(sin(x)*sin(y))/(x*y),注意括号
ax.plot_surface(X,Y,Z,rstride=1,cstride=1,cmap='rainbow')
#绘制3D图，后面的参数为调节图像的格式
plt.show()#展示图片

# %%
X.shape
# Out:
# (200, 200)

# %%
x = X.reshape(-1,1)
y = Y.reshape(-1,1)
z = Z.reshape(-1,1)
z.shape
# Out:
# (40000, 1)

# %%
data = np.hstack((x,y,z))
data
# Out:
# array([[-1.00000000e+01, -1.00000000e+01,  2.95958969e-03],
#        [-9.90000000e+00, -1.00000000e+01,  2.51423419e-03],
#        [-9.80000000e+00, -1.00000000e+01,  2.03441207e-03],
#        ...,
#        [ 9.70000000e+00,  9.90000000e+00,  1.29480622e-03],
#        [ 9.80000000e+00,  9.90000000e+00,  1.72827619e-03],
#        [ 9.90000000e+00,  9.90000000e+00,  2.13589526e-03]])

# %%
df = pd.DataFrame(data,columns=['X','Y','Z']) # 将第一维度数据转为为行，第二维度数据转化为列，即 3 行 2 列，并设置列标签
print(df)
# Out:
#           X     Y         Z
# 0     -10.0 -10.0  0.002960
# 1      -9.9 -10.0  0.002514
# 2      -9.8 -10.0  0.002034
# 3      -9.7 -10.0  0.001524
# 4      -9.6 -10.0  0.000988
# ...     ...   ...       ...
# 39995   9.5   9.9  0.000366
# 39996   9.6   9.9  0.000839
# 39997   9.7   9.9  0.001295
# 39998   9.8   9.9  0.001728
# 39999   9.9   9.9  0.002136
#
# [40000 rows x 3 columns]

# %%
df.to_csv("X Y Z.csv")

# %%
from autogluon.tabular import TabularPredictor
predictor = TabularPredictor(label="Z").fit(train_data="X Y Z.csv")
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20220807_051526\"
# Loaded data from: X Y Z.csv | Columns = 4 / 4 | Rows = 40000 -> 40000
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20220807_051526\"
# AutoGluon Version:  0.4.0
# Python Version:     3.9.7
# Operating System:   Windows
# Train Data Rows:    40000
# Train Data Columns: 3
# Label Column: Z
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.0, -0.2172289150366882, 0.0275, 0.14936)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    1859.37 MB
# 	Train Data (Original)  Memory Usage: 0.96 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['X', 'Y']
# 		('int', [])   : 1 | ['Unnamed: 0']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['X', 'Y']
# 		('int', [])   : 1 | ['Unnamed: 0']
# 	0.1s = Fit runtime
# 	3 features in original data used to generate 3 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.96 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.0625, Train Rows: 37500, Val Rows: 2500
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-0.0052	 = Validation score   (root_mean_squared_error)
# 	0.04s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-0.003	 = Validation score   (root_mean_squared_error)
# 	0.04s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 0.019092
# [2000]	valid_set's rmse: 0.0107237
# [3000]	valid_set's rmse: 0.00788123
# [4000]	valid_set's rmse: 0.00666796
# [5000]	valid_set's rmse: 0.00610919
# [6000]	valid_set's rmse: 0.00568449
# [7000]	valid_set's rmse: 0.00536938
# [8000]	valid_set's rmse: 0.00515078
# [9000]	valid_set's rmse: 0.00497017
# [10000]	valid_set's rmse: 0.00479734
# 	-0.0048	 = Validation score   (root_mean_squared_error)
# 	11.47s	 = Training   runtime
# 	1.28s	 = Validation runtime
# Fitting model: LightGBM ...
# [1000]	valid_set's rmse: 0.00259174
# [2000]	valid_set's rmse: 0.0017665
# [3000]	valid_set's rmse: 0.00146705
# [4000]	valid_set's rmse: 0.00131657
# [5000]	valid_set's rmse: 0.0012221
# [6000]	valid_set's rmse: 0.00114225
# [7000]	valid_set's rmse: 0.0010868
# [8000]	valid_set's rmse: 0.00104586
# [9000]	valid_set's rmse: 0.00101332
# [10000]	valid_set's rmse: 0.000980201
# 	-0.001	 = Validation score   (root_mean_squared_error)
# 	12.96s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	Warning: Reducing model 'n_estimators' from 300 -> 90 due to low memory. Expected memory usage reduced from 49.68% -> 15.0% of available memory...
# 	-0.0014	 = Validation score   (root_mean_squared_error)
# 	2.22s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-0.0017	 = Validation score   (root_mean_squared_error)
# 	124.1s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	Warning: Reducing model 'n_estimators' from 300 -> 92 due to low memory. Expected memory usage reduced from 48.72% -> 15.0% of available memory...
# 	-0.0011	 = Validation score   (root_mean_squared_error)
# 	0.91s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-0.0329	 = Validation score   (root_mean_squared_error)
# 	44.35s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-0.0031	 = Validation score   (root_mean_squared_error)
# 	1.59s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-0.0116	 = Validation score   (root_mean_squared_error)
# 	142.84s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# [1000]	valid_set's rmse: 0.0014841
# [2000]	valid_set's rmse: 0.00105494
# [3000]	valid_set's rmse: 0.00090767
# [4000]	valid_set's rmse: 0.000852181
# [5000]	valid_set's rmse: 0.000811223
# [6000]	valid_set's rmse: 0.000779734
# [7000]	valid_set's rmse: 0.000760377
# [8000]	valid_set's rmse: 0.00074369
# [9000]	valid_set's rmse: 0.000729293
# [10000]	valid_set's rmse: 0.000717159
# 	-0.0007	 = Validation score   (root_mean_squared_error)
# 	32.42s	 = Training   runtime
# 	1.67s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.0005	 = Validation score   (root_mean_squared_error)
# 	0.36s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 389.07s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20220807_051526\")

# %%
df = pd.read_csv("X Y Z.csv")
data = df.drop(columns = ["Y"])

# %%
data
# Out:
#        Unnamed: 0     X         Z
# 0               0 -10.0  0.002960
# 1               1  -9.9  0.002514
# 2               2  -9.8  0.002034
# 3               3  -9.7  0.001524
# 4               4  -9.6  0.000988
# ...           ...   ...       ...
# 39995       39995   9.5  0.000366
# 39996       39996   9.6  0.000839
# 39997       39997   9.7  0.001295
# 39998       39998   9.8  0.001728
# 39999       39999   9.9  0.002136
#
# [40000 rows x 3 columns]

# %%
z_pred = predictor.predict(df)

# %%
Z_pred = z_pred.values.reshape((200,200))

# %%
matplotlib notebook

# %%
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

figure = plt.figure(figsize=(10,10))
ax = Axes3D(figure)#设置图像为三维格式
X = np.arange(-10,10,0.1)
Y = np.arange(-10,10,0.1)#X,Y的范围
X,Y = np.meshgrid(X,Y)#绘制网格
Z=(np.sin(X)*np.sin(Y))/(X*Y)#f(x,y)=(sin(x)*sin(y))/(x*y),注意括号
ax.plot_surface(X,Y,Z,rstride=10,cstride=10,color="blue")

ax.scatter(X[::10,::10],Y[::10,::10],Z_pred[::10,::10],s=200,color="red",marker='^')

#绘制3D图，后面的参数为调节图像的格式
plt.show()#展示图片
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
figure = plt.figure(figsize=(10,10))
ax = Axes3D(figure)#设置图像为三维格式
ax.plot_surface(X,Y,Z_pred,rstride=100,cstride=100,color="red")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
